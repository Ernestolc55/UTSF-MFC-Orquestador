# %%
# UTSF-MFC v8.8.8 - Orquestador con Telegram + Neon
import os
import requests
import json
from datetime import datetime

# Leer secretos (los configuraremos luego en GitHub Actions)
TELEGRAM_TOKEN = os.getenv("TELEGRAM_BOT_TOKEN")
NEON_DB_URL = os.getenv("NEON_DB_URL")

# Función para enviar mensaje a Telegram
def send_telegram(chat_id, text):
    url = f"https://api.telegram.org/bot{TELEGRAM_TOKEN}/sendMessage"
    payload = {"chat_id": chat_id, "text": text}
    requests.post(url, json=payload)

# Función para guardar en Neon (memoria compartida)
def guardar_en_memoria(contenido):
    # Aquí conectaremos con PostgreSQL más adelante
    print("Guardando en Neon:", contenido[:100])

# Simular una ronda de investigación (luego llamarás a Kimi, Claude, etc.)
def investigar(pregunta):
    # Por ahora, respuesta de prueba
    return f"[Simulación] Respuesta a: {pregunta}"

# === MAIN ===
if __name__ == "__main__":
    pregunta = "¿Cuál es el siguiente paso en UTSF-MFC?"
    respuesta = investigar(pregunta)
    guardar_en_memoria(respuesta)
    # Enviamos un mensaje a Telegram (necesitas saber tu chat_id)
    send_telegram("TU_CHAT_ID", f"Resultado:\n{respuesta}")
